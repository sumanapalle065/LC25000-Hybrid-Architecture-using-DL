# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanapalle065/LC25000-Hybrid-Architecture-using-DL/blob/Testing-Results/LC25000_Hybrid_Arc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
import glob # library to retrieve file paths matching a pattern
import matplotlib.pyplot as matplib # library for plotting graphs
import random # Random library for random number generation
from PIL import Image, ImageEnhance
from tqdm import tqdm # import TQDM library for displaying progress bars within loops
from skimage.color import rgb2lab, lab2rgb
import tensorflow as tf
from tensorflow.keras import layers, models, backend as K
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score # Sklearn metrics for classification performance
import seaborn as sns
from sklearn.metrics import confusion_matrix
import itertools
from sklearn.preprocessing import label_binarize # Funciton for converting labels to binary format for multiclass problems
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.utils import to_categorical

# %%
# !unzip "/content/drive/MyDrive/LC25000.zip"

# %%
# In the lung_colon_image_set directory and its subdirectories, use glob to retrieve all image file paths.
lung_colon_image_set_df=glob.glob("/content/lung_colon_image_set/*/*/*")

# %%
lung_colon_image_set_df
# Out:
# ['/content/lung_colon_image_set/colon_image_sets/colon_n/colonn583.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2257.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4927.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn476.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2862.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2056.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2894.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn871.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4534.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2023.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2468.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1794.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4141.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1327.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4140.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4147.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4086.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2111.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4956.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2803.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1986.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1108.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3205.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3699.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2200.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3665.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2153.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2325.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn305.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2031.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2753.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1570.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3397.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2961.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3928.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3985.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3020.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1687.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4570.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn101.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn318.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn123.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2783.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn392.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1995.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3882.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2504.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4992.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3941.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2343.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4505.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1278.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3077.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4915.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4896.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2289.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn266.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4586.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1698.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2254.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn841.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2562.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4316.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3808.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn714.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4713.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2215.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn384.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3904.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2357.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4498.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2663.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2123.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn847.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3112.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4833.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3703.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2030.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1572.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3653.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3036.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn371.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3740.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1369.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3814.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4643.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3264.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1979.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn564.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4024.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2917.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4801.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3496.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1424.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2682.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4930.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1246.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4009.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1269.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3395.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2630.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4182.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn91.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3418.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2043.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3439.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1636.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2755.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2680.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1100.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3885.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1571.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1380.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn244.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3377.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4748.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2391.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2107.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn363.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3859.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn510.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2140.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1516.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2487.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2824.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3049.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4297.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn764.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1693.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn759.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1691.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn225.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn747.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1421.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4310.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1558.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1639.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3035.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1133.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1459.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2818.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3890.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3717.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2262.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3403.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2010.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn942.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4114.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3012.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4974.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1363.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn537.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4734.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn660.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2498.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn925.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1124.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4142.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn596.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3240.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1258.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2251.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3332.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn920.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn720.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4165.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2021.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2283.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn678.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3742.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn984.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1744.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2353.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2913.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn413.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2191.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn525.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3535.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3860.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn863.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3476.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4189.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn346.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4443.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3101.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1890.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1472.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn815.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1035.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3790.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4627.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3424.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4860.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2968.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1898.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1612.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4094.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4545.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2314.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1835.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2724.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1177.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1113.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3599.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4446.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2673.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2261.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4976.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1490.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn201.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3006.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4933.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn661.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3959.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2138.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1005.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn514.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2263.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1410.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn135.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2808.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2860.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1820.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1248.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1458.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2507.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2664.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2408.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2579.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3178.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2045.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1155.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4047.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1992.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4548.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2522.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3526.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2168.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1251.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2172.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn772.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4096.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3747.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4968.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4381.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4694.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3362.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2365.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn499.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3493.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4733.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn165.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colon
jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn125.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4943.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1378.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1309.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn616.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1790.jpeg',
# ...
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2419.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3715.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1452.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3061.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1816.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4554.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn336.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3895.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3566.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4263.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn28.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3693.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn656.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn668.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3713.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1891.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn790.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3912.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3265.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4878.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1705.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2252.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2619.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1562.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4848.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4865.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1463.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1810.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn625.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3039.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4442.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2363.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3119.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3608.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3293.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1020.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1083.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2052.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2884.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1440.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2265.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn465.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1021.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3408.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2240.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3641.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1761.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3004.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3329.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3974.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4408.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3390.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1420.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3753.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4211.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2260.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2738.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1751.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1842.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4762.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn662.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2179.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1634.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn786.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1451.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn477.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2653.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn327.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3867.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4555.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn217.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4496.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2141.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn840.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4454.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2832.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1469.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1306.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1416.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1908.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3322.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2814.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3374.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4247.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn272.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2465.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3287.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2563.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2214.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3249.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3396.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4864.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2979.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn374.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3903.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2296.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4749.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3009.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2996.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3413.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1733.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3121.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1665.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3605.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2020.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3519.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1031.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2618.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn278.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3380.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn317.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn988.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1683.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn324.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3349.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2329.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1003.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1354.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4894.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3433.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn210.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn451.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn531.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1689.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4283.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2773.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3854.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3347.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4402.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn494.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4163.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3524.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn553.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3695.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn956.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1485.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3391.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4626.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4295.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1804.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4437.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1330.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2164.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4440.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1086.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4812.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3623.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1392.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4827.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1082.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4159.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2719.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4794.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1847.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4911.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4137.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4540.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3081.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2196.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4003.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn980.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3965.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1423.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2901.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn490.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2927.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2534.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3429.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2152.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3915.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2676.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn666.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3845.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3731.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2581.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2582.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1542.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3226.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn622.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4475.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2104.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1335.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn298.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn286.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4787.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn81.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4222.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4708.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3498.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4740.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn635.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1467.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3666.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4793.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4732.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3505.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3082.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1205.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3096.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4873.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4229.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4088.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn388.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn4530.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1581.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn3702.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1199.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn2716.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1321.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn1998.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn682.jpeg',
#  '/content/lung_colon_image_set/colon_image_sets/colon_n/colonn839.jpeg',
#  ...]

# %%
# Choose a randomly selected image path from
image_path = random.choice(lung_colon_image_set_df)  # Choosen a randomly selected image path from the dataset
image = cv2.imread(image_path)
# Change the color space of the image from BGR color space to RGB color space since we know OpenCV reads in images by default in BGR
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# Display the image using Matplotlib
matplib.imshow(image)  # Displays the image on the plot
matplib.axis('off')  # Hides the axes for a cleaner view of the image
matplib.show()  # Shows the plot with the image

# %%
import matplotlib.pyplot as plt

# Initializing lists to store image widths and heights
widths = []
heights = []

# Loop through each image path in the dataset
for img_path in tqdm(lung_colon_image_set_df):
    img = cv2.imread(image_path)
    if img is not None:
        h, w = img.shape[:2]  # Get image height and width
        heights.append(h)
        widths.append(w)

# Plot the histograms for widths and heights
plt.figure(figsize=(12, 5))

# Width Histogram
plt.subplot(1, 2, 1)
plt.hist(widths, bins=30, color='skyblue', edgecolor='black')
plt.xlabel("Image Width")
plt.ylabel("Frequency")
plt.title("Histogram of Image Widths")

# Height Histogram
plt.subplot(1, 2, 2)
plt.hist(heights, bins=30, color='salmon', edgecolor='black')
plt.xlabel("Image Height")
plt.ylabel("Frequency")
plt.title("Histogram of Image Heights")

plt.tight_layout()
plt.show()

# Cluster Plot for Widths and Heights
import pandas as pd

# Convert the data to a DataFrame for easy plotting
df = pd.DataFrame({'Width': widths, 'Height': heights})

# Plot a cluster plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Width', y='Height', data=df, hue=None, palette='viridis')
plt.xlabel("Image Width")
plt.ylabel("Image Height")
plt.title("Cluster Plot of Image Dimensions")
plt.show()
# Out:
# 100%|██████████| 25000/25000 [01:11<00:00, 351.38it/s]
# <ipython-input-8-076f67684bc8>:43: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='Width', y='Height', data=df, hue=None, palette='viridis')

# %%
# Suppress warnings to prevent useless output in the console
import warnings
warnings.filterwarnings("ignore")

# Function for simple stain normalization without PCA
def simple_stain_normalization(img, target_img, alpha=1):
    # Convert both images from RGB to LAB color space (LAB is better for color manipulation)
    img_lab = rgb2lab(img)  # Convert the input image to LAB color space
    target_lab = rgb2lab(target_img)  # Convert the target image to LAB color space

    # Compute the mean and standard deviation of the LAB channels for both images
    img_mean = np.mean(img_lab, axis=(0, 1), keepdims=True)  # Mean across the height and width (per channel)
    img_std = np.std(img_lab, axis=(0, 1), keepdims=True)  # Standard deviation across the height and width (per channel)
    target_mean = np.mean(target_lab, axis=(0, 1), keepdims=True)  # Mean of the target image (per channel)
    target_std = np.std(target_lab, axis=(0, 1), keepdims=True)  # Standard deviation of the target image (per channel)

   # Normalize the input image based on the mean and std of the target image
    img_normalized = (img_lab - img_mean) / img_std * target_std + target_mean  # Adjust to match the target image's color stats

    # Transpose the normalized image from LAB back to RGB
    img_rgb_normalized = lab2rgb(img_normalized)  # Convert back to RGB color space

    # Return the normalized image (scaled back to 0-255 range)
    return (img_rgb_normalized * 255).astype(np.uint8)

# Lists to hold the processed images and their corresponding labels
processed_images = []  # List to hold the processed images
labels = []  # List to hold the labels corresponding to each image

# Define a label map to associate image categories with numerical labels
label_map = {
    "lung_aca": 0,  # Adenocarcinoma of the lung
    "colon_n": 1,  # Normal colon tissue
    "lung_n": 2,  # Normal lung tissue
    "lung_scc": 3,  # Squamous cell carcinoma of the lung
    "colon_aca": 4,  # Adenocarcinoma of the colon
}

# Path to a target image (used for stain normalization)
target_img_path = '/content/lung_colon_image_set/colon_image_sets/colon_aca/colonca4273.jpeg'
target_img = cv2.imread(target_img_path)  # Read the target image from disk
target_img = cv2.resize(target_img, (224, 224))  # Resize the target image to 224x224 pixels

# Iterate over each image in the dataset (from lung_colon_image_set_df)
for img_path in tqdm(lung_colon_image_set_df):
    img = cv2.imread(img_path)  # Read the image from the specified path
    if img is None:  # Skip if the image couldn't be loaded (i.e., it's None)
        continue

    img = cv2.resize(img, (128, 128))  # Resize the image to match the target image size (224x224)

   # Use the stain normalization function to the image with the target image
    img = simple_stain_normalization(img, target_img)

    # Append the normalized image to list of normalized images
    processed_images.append(img)

    # Extract the label of the image from the folder name
    label = img_path.split(os.path.sep)[-2]  # Get the parent folder (label) from the image path
    if label in label_map:  # If the label is in the predefined map
        labels.append(label_map[label])  # Append the numerical label to the labels list

# Convert the lists of processed images and labels to NumPy arrays
processed_images = np.array(processed_images)  # Array of processed images
labels = np.array(labels)  # Array of labels

# Print the completion message with the total number of processed images
print("Preprocessing complete. Total processed images:", len(processed_images))
# Out:
# 100%|██████████| 25000/25000 [07:33<00:00, 55.14it/s]
# Preprocessing complete. Total processed images: 25000

# %%
# Convert processed_images to a NumPy array
processed_images_array = np.array(processed_images)

# Convert Labels to a NumPy array
labels_array = np.array(labels)

# Print the shapes of the arrays to verify they are NumPy arrays
print("Shape of processed_images_array:", processed_images_array.shape)
print("Shape of labels_array:", labels_array.shape)
# Out:
# Shape of processed_images_array: (25000, 128, 128, 3)
# Shape of labels_array: (25000,)

# %%
from sklearn.model_selection import train_test_split
# Split the lung_colon_image_set_df into training and testing sets (80% train, 20% test)
Xtrain_lung_colon_image_set_df, Xtest_lung_colon_image_set_df, ytrain_lung_colon_image_set_df, ytest_lung_colon_image_set_df = train_test_split(
    processed_images_array, labels_array, test_size=0.2, random_state=100
)

# %%
#Print the shape of the trainning images
print("X_train shape:", Xtrain_lung_colon_image_set_df.shape)  # Prints the shape of the training image data (features)
# Print the shape of the testing images
print("X_test shape:", Xtest_lung_colon_image_set_df.shape)  # Prints the shape of the testing image data (features)

# Print the shape of the trainning labels
print("y_train shape:", ytrain_lung_colon_image_set_df.shape)  # Prints the shape of the training labels (targets)

# Print the shape of the testing labels
print("y_test shape:", ytest_lung_colon_image_set_df.shape)  # Prints the shape of the testing labels (targets)
# Out:
# X_train shape: (20000, 128, 128, 3)
# X_test shape: (5000, 128, 128, 3)
# y_train shape: (20000,)
# y_test shape: (5000,)

# %%
ytrain_lung_colon_image_set_df= to_categorical(ytrain_lung_colon_image_set_df, num_classes=5)
ytest_lung_colon_image_set_df = to_categorical(ytest_lung_colon_image_set_df, num_classes=5)

# %%
# Print the shape of the training labels
print("y_train shape:", ytrain_lung_colon_image_set_df.shape) # Prints the shape of the training labels (targets)

# Print the shape of the testing labels
print("y_test shape:", ytest_lung_colon_image_set_df.shape) # Prints the shape of the testing labels (targets)
# Out:
# y_train shape: (20000, 5)
# y_test shape: (5000, 5)

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
# Lambda function for grafting GLPP features
def graft_glpp_features(cnn_features, glpp_features):
    # Concatenate automated CNN features and handcrafted GLPP features
    return K.concatenate([cnn_features, glpp_features], axis=-1)

# Define the custom feature grafting layer
class GLPPLayer(layers.Layer):
    def __init__(self):
        super(GLPPLayer, self).__init__()

    def call(self, cnn_features, glpp_features):
        return graft_glpp_features(cnn_features, glpp_features)

# Define the ColonNet model
def ColonNet(input_shape=(128, 128, 3), num_classes=5, glpp_feature_size=100):
    # Input for image
    input_image = layers.Input(shape=input_shape, name="Image_Input")

    # Pretrained base model (InceptionV3) for feature extraction
    base_model = InceptionV3(include_top=False, weights="imagenet", input_tensor=input_image)
    base_model.trainable = False  # Freeze the base model layers

    # Automated CNN feature extraction
    cnn_features = layers.GlobalAveragePooling2D()(base_model.output)

    # Input for manually extracted GLPP features
    input_glpp = layers.Input(shape=(glpp_feature_size,), name="GLPP_Input")

    # Graft the GLPP features into the network (manual + automated features)
    grafted_features = GLPPLayer()(cnn_features, input_glpp)

    # Fully connected layers after feature fusion
    x = layers.Dense(1020, activation="relu")(grafted_features)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(1020, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    # Output layer (Softmax for multi-class classification)
    output = layers.Dense(num_classes, activation="softmax", name="Output")(x)

    # Define the final model
    model = models.Model(inputs=[input_image, input_glpp], outputs=output, name="ColonNet")

    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss="categorical_crossentropy", metrics=["accuracy"])

    return model
# Example usage:
input_shape = (128, 128, 3)
num_classes = 5  #  5 classes (lung and colon cancer types)
glpp_feature_size = 100  # Size of GLPP feature vector

# Create ColonNet model
colonnet_model = ColonNet(input_shape=input_shape, num_classes=num_classes, glpp_feature_size=glpp_feature_size)

# Print the model summary
colonnet_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "ColonNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Image_Input (InputLayer)  │ (None, 128, 128, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 63, 63, 32)     │            864 │ Image_Input[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 63, 63, 32)     │             96 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 63, 63, 32)     │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 61, 61, 32)     │          9,216 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 61, 61, 32)     │             96 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 61, 61, 32)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 61, 61, 64)     │         18,432 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 61, 61, 64)     │            192 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 61, 61, 64)     │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 30, 30, 64)     │              0 │ activation_2[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 30, 30, 80)     │          5,120 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 30, 30, 80)     │            240 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 30, 30, 80)     │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 28, 28, 192)    │        138,240 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 28, 28, 192)    │            576 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 28, 28, 192)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 13, 13, 192)    │              0 │ activation_4[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 13, 13, 64)     │         12,288 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 13, 13, 64)     │            192 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 13, 13, 64)     │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 13, 13, 48)     │          9,216 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 13, 13, 96)     │         55,296 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 13, 13, 48)     │            144 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 13, 13, 96)     │            288 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 13, 13, 48)     │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 13, 13, 96)     │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d         │ (None, 13, 13, 192)    │              0 │ max_pooling2d_1[0][0]  │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 13, 13, 64)     │         12,288 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 13, 13, 64)     │         76,800 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 13, 13, 96)     │         82,944 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 13, 13, 32)     │          6,144 │ average_pooling2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 13, 13, 64)     │            192 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 13, 13, 64)     │            192 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 13, 13, 96)     │            288 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 13, 13, 32)     │             96 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 13, 13, 64)     │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 13, 13, 64)     │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 13, 13, 96)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 13, 13, 32)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mixed0 (Concatenate)      │ (None, 13, 13, 256)    │              0 │ activation_5[0][0],    │
# │                           │                        │                │ activation_7[0][0],    │
# │                           │                        │                │ activation_10[0][0],   │
# │                           │                        │                │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 13, 13, 64)     │         16,384 │ mixed0[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 13, 13, 64)     │            192 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 13, 13, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 13, 13, 48)     │         12,288 │ mixed0[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 13, 13, 96)     │         55,296 │ activation_15[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 13, 13, 48)     │            144 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 13, 13, 96)     │            288 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 13, 13, 48)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 13, 13, 96)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_1       │ (None, 13, 13, 256)    │              0 │ mixed0[0][0]           │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 13, 13, 64)     │         16,384 │ mixed0[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 13, 13, 64)     │         76,800 │ activation_13[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 13, 13, 96)     │         82,944 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 13, 13, 64)     │         16,384 │ average_pooling2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 13, 13, 64)     │            192 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 13, 13, 64)     │            192 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 13, 13, 96)     │            288 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 13, 13, 64)     │            192 │ conv2d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 13, 13, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 13, 13, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 13, 13, 96)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 13, 13, 64)     │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mixed1 (Concatenate)      │ (None, 13, 13, 288)    │              0 │ activation_12[0][0],   │
# │                           │                        │                │ activation_14[0][0],   │
# │                           │                        │                │ activation_17[0][0],   │
# │                           │                        │                │ activation_18[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 13, 13, 64)     │         18,432 │ mixed1[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None,
0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_89 (Conv2D)        │ (None, 2, 2, 448)      │        917,504 │ mixed9[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_89    │ (None, 2, 2, 448)      │          1,344 │ conv2d_89[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_89             │ (None, 2, 2, 448)      │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_86 (Conv2D)        │ (None, 2, 2, 384)      │        786,432 │ mixed9[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_90 (Conv2D)        │ (None, 2, 2, 384)      │      1,548,288 │ activation_89[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_86    │ (None, 2, 2, 384)      │          1,152 │ conv2d_86[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_90    │ (None, 2, 2, 384)      │          1,152 │ conv2d_90[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_86             │ (None, 2, 2, 384)      │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_90             │ (None, 2, 2, 384)      │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_87 (Conv2D)        │ (None, 2, 2, 384)      │        442,368 │ activation_86[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_88 (Conv2D)        │ (None, 2, 2, 384)      │        442,368 │ activation_86[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_91 (Conv2D)        │ (None, 2, 2, 384)      │        442,368 │ activation_90[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_92 (Conv2D)        │ (None, 2, 2, 384)      │        442,368 │ activation_90[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ average_pooling2d_8       │ (None, 2, 2, 2048)     │              0 │ mixed9[0][0]           │
# │ (AveragePooling2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_85 (Conv2D)        │ (None, 2, 2, 320)      │        655,360 │ mixed9[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_87    │ (None, 2, 2, 384)      │          1,152 │ conv2d_87[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_88    │ (None, 2, 2, 384)      │          1,152 │ conv2d_88[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_91    │ (None, 2, 2, 384)      │          1,152 │ conv2d_91[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_92    │ (None, 2, 2, 384)      │          1,152 │ conv2d_92[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_93 (Conv2D)        │ (None, 2, 2, 192)      │        393,216 │ average_pooling2d_8[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_85    │ (None, 2, 2, 320)      │            960 │ conv2d_85[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_87             │ (None, 2, 2, 384)      │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_88             │ (None, 2, 2, 384)      │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_91             │ (None, 2, 2, 384)      │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_92             │ (None, 2, 2, 384)      │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_93    │ (None, 2, 2, 192)      │            576 │ conv2d_93[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_85             │ (None, 2, 2, 320)      │              0 │ batch_normalization_8… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mixed9_1 (Concatenate)    │ (None, 2, 2, 768)      │              0 │ activation_87[0][0],   │
# │                           │                        │                │ activation_88[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 2, 2, 768)      │              0 │ activation_91[0][0],   │
# │ (Concatenate)             │                        │                │ activation_92[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_93             │ (None, 2, 2, 192)      │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ mixed10 (Concatenate)     │ (None, 2, 2, 2048)     │              0 │ activation_85[0][0],   │
# │                           │                        │                │ mixed9_1[0][0],        │
# │                           │                        │                │ concatenate_1[0][0],   │
# │                           │                        │                │ activation_93[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 2048)           │              0 │ mixed10[0][0]          │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ GLPP_Input (InputLayer)   │ (None, 100)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ glpp_layer (GLPPLayer)    │ (None, 2148)           │              0 │ global_average_poolin… │
# │                           │                        │                │ GLPP_Input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1020)           │      2,191,980 │ glpp_layer[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1020)           │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1020)           │      1,041,420 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 1020)           │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Output (Dense)            │ (None, 5)              │          5,105 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 25,041,289 (95.52 MB)
#  Trainable params: 3,238,505 (12.35 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
glpp_train = np.random.rand(Xtrain_lung_colon_image_set_df.shape[0], 100)  # Generating Training Features (100 features for each sample randomly)
glpp_test = np.random.rand(Xtest_lung_colon_image_set_df.shape[0], 100)    # Generating Test Features (100 features for each sample randomly)

history = colonnet_model.fit(   # Fitting a ColonNet Model
    x=[Xtrain_lung_colon_image_set_df, glpp_train],  # Input to the model: Image data and the random features for training
    y=ytrain_lung_colon_image_set_df,  # Labels for training
    epochs = 250,
    batch_size = 232,
    validation_data = ([Xtest_lung_colon_image_set_df, glpp_test], ytest_lung_colon_image_set_df),  # Validation data: Now a list with image data and GLPP features
)
#history = colonnet_model.fit(   # Fitting a ColonNet Model
 #   x=[Xtrain_lung_colon_image_set_df, glpp_train],  # Input to the model: Image data and the random features for training
  #  y=ytrain_lung_colon_image_set_df,  # Labels for training
#epochs = 250,
#batch_size = 232,
#validation_data = (Xtest_lung_colon_image_set_df, glpp_test),  # Validation data. NO. see below
#)
# Out:
# Epoch 1/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 54s 372ms/step - accuracy: 0.2819 - loss: 51.9931 - val_accuracy: 0.4742 - val_loss: 1.4262
# Epoch 2/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.3516 - loss: 1.8670 - val_accuracy: 0.4584 - val_loss: 1.3316
# Epoch 3/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.3668 - loss: 1.5384 - val_accuracy: 0.4830 - val_loss: 1.3151
# Epoch 4/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.3785 - loss: 1.4626 - val_accuracy: 0.4844 - val_loss: 1.2644
# Epoch 5/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.4025 - loss: 1.4157 - val_accuracy: 0.5078 - val_loss: 1.2017
# Epoch 6/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.4077 - loss: 1.3789 - val_accuracy: 0.5028 - val_loss: 1.2320
# Epoch 7/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4217 - loss: 1.3694 - val_accuracy: 0.5114 - val_loss: 1.1707
# Epoch 8/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4198 - loss: 1.3753 - val_accuracy: 0.5208 - val_loss: 1.1681
# Epoch 9/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4281 - loss: 1.3578 - val_accuracy: 0.5252 - val_loss: 1.1715
# Epoch 10/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4301 - loss: 1.3384 - val_accuracy: 0.5370 - val_loss: 1.1311
# Epoch 11/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4475 - loss: 1.2994 - val_accuracy: 0.5248 - val_loss: 1.1826
# Epoch 12/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4461 - loss: 1.2962 - val_accuracy: 0.5190 - val_loss: 1.1530
# Epoch 13/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4419 - loss: 1.3018 - val_accuracy: 0.5294 - val_loss: 1.0885
# Epoch 14/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4371 - loss: 1.3078 - val_accuracy: 0.5266 - val_loss: 1.1271
# Epoch 15/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4253 - loss: 1.3117 - val_accuracy: 0.5528 - val_loss: 1.1137
# Epoch 16/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4316 - loss: 1.3106 - val_accuracy: 0.5638 - val_loss: 1.0718
# Epoch 17/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4457 - loss: 1.2741 - val_accuracy: 0.5436 - val_loss: 1.1135
# Epoch 18/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4278 - loss: 1.2917 - val_accuracy: 0.5480 - val_loss: 1.0870
# Epoch 19/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4517 - loss: 1.2586 - val_accuracy: 0.5508 - val_loss: 1.0905
# Epoch 20/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4520 - loss: 1.2535 - val_accuracy: 0.5582 - val_loss: 1.1339
# Epoch 21/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4466 - loss: 1.2517 - val_accuracy: 0.5682 - val_loss: 1.0563
# Epoch 22/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4632 - loss: 1.2292 - val_accuracy: 0.5494 - val_loss: 1.0658
# Epoch 23/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4478 - loss: 1.2472 - val_accuracy: 0.5592 - val_loss: 1.0634
# Epoch 24/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4694 - loss: 1.2224 - val_accuracy: 0.5648 - val_loss: 1.0558
# Epoch 25/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4715 - loss: 1.2115 - val_accuracy: 0.5756 - val_loss: 1.0369
# Epoch 26/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4729 - loss: 1.2020 - val_accuracy: 0.5706 - val_loss: 1.0269
# Epoch 27/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4698 - loss: 1.2094 - val_accuracy: 0.5628 - val_loss: 1.0671
# Epoch 28/250
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.6392 - loss: 0.8523 - val_accuracy: 0.5928 - val_loss: 0.9553

# %%
# Plot training & validation accuracy values
matplib.plot(history.history['accuracy'])  # Plot the accuracy values for the training data
matplib.plot(history.history['val_accuracy'])  # Plot the accuracy values for the validation data

# Set title and labels
matplib.title('Model accuracy')  # Title of the accuracy plot
matplib.ylabel('Accuracy')  # Y-axis label for accuracy
matplib.xlabel('Epoch')  # X-axis label for epochs
matplib.legend(['Train', 'Test'], loc='upper left')
# Legend showing which line is the training set and which is the validation set
matplib.show()  # Plot the accuracy
# Plot the training & validation loss values
matplib.plot(history.history['loss'])  # Plot the training losses
matplib.plot(history.history['val_loss'])  # Plot the validation losses

# Set the title and labels for the loss plot
matplib.title('Model loss')  # Title of the loss plot
matplib.ylabel('Loss')
# Y-axis label for loss
matplib.xlabel('Epoch')
# X-axis label for epochs
matplib.legend(['Train', 'Test'], loc='upper left')
# Legend indicating which line is for training and which is for validation
matplib.show()
# Show the loss plot

# %%
# predict the class probabilities for the training set
ytrain_lung_colon_image_set_df_pred = colonnet_model.predict([Xtrain_lung_colon_image_set_df, glpp_train])  # predict the class probabilities for the training set using the model

#get the predicted classes by selecting the class with the highest probability
ytrain_lung_colon_image_set_df_pred_classes = np.argmax(ytrain_lung_colon_image_set_df_pred, axis=1)  # convert probabilities to predicted class labels (the class with highest probability)

#get the true class labels (if the target is one-hot encoded, use argmax to convert to class labels)
ytrain_lung_colon_image_set_df_true_classes = np.argmax(ytrain_lung_colon_image_set_df, axis=1)  # Get the class labels from the one-hot encoded labels

# Evaluate the model on the training set
train_accuracy = accuracy_score(ytrain_lung_colon_image_set_df_true_classes, ytrain_lung_colon_image_set_df_pred_classes)  # accuracy of the model
train_precision = precision_score(ytrain_lung_colon_image_set_df_true_classes, ytrain_lung_colon_image_set_df_pred_classes, average='weighted')  # weighted precision of the model
train_recall = recall_score(ytrain_lung_colon_image_set_df_true_classes, ytrain_lung_colon_image_set_df_pred_classes, average='weighted')  # weighted recall of the model
train_f1 = f1_score(ytrain_lung_colon_image_set_df_true_classes, ytrain_lung_colon_image_set_df_pred_classes, average='weighted')  # weighted F1-score of the model

# Print the evaluation metrics
# Print the a title indicating metrics for training set
print("Training Set Metrics:")

# Print the accuracy of the model for the training set
# 'train_accuracy' should have been calculated beforehand, for example with `accuracy_score(y_train_true, y_train_pred)`
print("Accuracy:", train_accuracy)

# Print the precision of the model for the training set
# 'train_precision' should have been calculated beforehand, for example with `precision_score(y_train_true, y_train_pred, average='weighted')`
print("Precision:", train_precision)

# Print the recall of the model for the training set
# _recall_train_ should be computed ahead of time, say by `recall_score(y_train_true, y_train_pred, average='weighted')`
print("Recall:", train_recall)

# _f1_score_model_ on training set
# train_f1 should be computed ahead of time, say by `f1_score(y_train_true, y_train_pred, average='weighted')`
print("F1-Score:", train_f1)
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step
# Training Set Metrics:
# Accuracy: 0.6324
# Precision: 0.6961952305424345
# Recall: 0.6324
# F1-Score: 0.6343855736548816

# %%
import matplotlib.pyplot
# Predict class probabilities for training set
ytrain_lung_colon_image_set_df_pred = colonnet_model.predict([Xtrain_lung_colon_image_set_df, glpp_train])

# Extract predicted class labels
ytrain_lung_colon_image_set_df_pred_classes = np.argmax(ytrain_lung_colon_image_set_df_pred, axis=1)

# Extract true class labels
ytrain_lung_colon_image_set_df_true_classes = np.argmax(ytrain_lung_colon_image_set_df, axis=1)

# Compute confusion matrix
cm = confusion_matrix(ytrain_lung_colon_image_set_df_true_classes, ytrain_lung_colon_image_set_df_pred_classes)

#new figure for the confusion matrix
matplib.figure(figsize=(8, 6))  # Set the figure size to 8x6 inches

# heatmap visualization of the confusion matrix
sns.heatmap(
    cm,  # The confusion matrix data
    annot=True,  # Annotate the heatmap cells with the values from the confusion matrix
    fmt='d',  # Format the annotations as integers
    cmap='Blues',  # Use a blue color palette for the heatmap
    xticklabels=label_map.keys(),  # Set x-axis tick labels using class names from `label_map`
    yticklabels=label_map.keys()   # Set y-axis tick labels using class names from `label_map`
)

# Add a label to the x-axis 'Predicted Label'
matplib.xlabel('Predicted Label')

# Add a label to the y-axis 'True Label'
matplib.ylabel('True Label')

# Add title to the confusion matrix plot
matplib.title('Confusion Matrix - Training Set')

# show the confusion matrix plot
matplib.show()
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step

# %%
# Calculate sensitivity, also referred to as the recall for the positive class
# Formula: True Positives cm[0,0] by total actual positives cm[0,0]+ False Negatives cm[0,1]
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity : ', sensitivity )
# Calculate specificity, which is the ability to correctly classify true negatives
# Formula: True Negatives cm[1,1] by total actual negatives cm[1,0] + True Negatives cm[1,1]
specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : ', specificity)
# Out:
# Sensitivity :  0.9763391390075583
# Specificity :  0.9597832287507131

# %%
# True labels binarization for ROC curve computation

ytrain_lung_colon_image_set_df_bin = label_binarize(ytrain_lung_colon_image_set_df_true_classes, classes=list(range(5)))

# Dictionaries for FPR, TPR and AUC of each class
fpr = dict()
tpr = dict()
roc_auc = dict()

# All iterations to calculate FPR, TPR, and AUC values
for i in range(5):
    fpr[i], tpr[i], _ = roc_curve(ytrain_lung_colon_image_set_df_bin[:, i], ytrain_lung_colon_image_set_df_pred[:, i])  # Calculate ROC curve
    roc_auc[i] = auc(fpr[i], tpr[i])  # Calculating the AUC for the current class

# This block creates a new figure for an ROC plot
matplib.figure(figsize=(8, 6))

# The for loop plots the ROC curve for each class
for i in range(5):
    matplib.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')  # Plot ROC curve with AUC

# Plotting the diagonal line which is referred to as a line for the random classifier
matplib.plot([0, 1], [0, 1], 'k--')

# Plotting the receiver operating characteristic curve
matplib.xlim([0.0, 1.0])  # X-axis: False Positive Rate
matplib.ylim([0.0, 1.05])  # Y-axis: True Positive Rate

# Set plot labels and title
matplib.xlabel('False Positive Rate')
matplib.ylabel('True Positive Rate')
matplib.title('Receiver Operating Characteristic (ROC) Curve - Training Set')

# Displaying the legend with AUC for each class
matplib.legend(loc="lower right")

# Display the plot
matplib.show()

# %% [markdown]
# # Testing Results

# %%
# Use the model to predict class probabilities for every sample
y_pred_prob = colonnet_model.predict([Xtest_lung_colon_image_set_df, glpp_test])

# Get class predictions by taking the index of the maximum probability for each sample.
y_pred = np.argmax(y_pred_prob, axis=1)

# Convert true labels from one-hot encoding to their corresponding class indices
y_true = np.argmax(ytest_lung_colon_image_set_df, axis=1)

# Calculate accuracy, which is the percentage of correctly predicted labels
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy}")

# Accuracy of positive predictions by computing the weighted average of precision
precision = precision_score(y_true, y_pred, average='weighted')
print(f"Precision: {precision}")

# Measure of recall which plots the model's ability to retrieve all the positive instances
recall = recall_score(y_true, y_pred, average='weighted')
print(f"Recall: {recall}")

# Compute the F1-score, which is the harmonic mean of precision and recall
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"F1-score: {f1}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step
# Accuracy: 0.593
# Precision: 0.6512003990918978
# Recall: 0.593
# F1-score: 0.5938106751023275

# %%
# Generate a confusion matrix with true labels and predicted labels
cm = confusion_matrix(y_true, y_pred)
# Create a figure for plotting the heatmap
matplib.figure(figsize=(10, 8))
# Plot confusion matrix as a heatmap using Seaborn
# Show values from the confusion matrix within the cells of the heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(5), yticklabels=range(5))
# Title for the x-axis, 'Predicted Labels'
matplib.xlabel('Predicted Labels')
# Title for the y-axis, 'True Labels'
matplib.ylabel('True Labels')
# Add a title to the heatmap
matplib.title('Confusion Matrix ')
# Diplays the confusion matrix heatmap
matplib.show()

# %%
# Calculate sensitivity, also referred to as the recall for the positive class
# Formula: True Positives cm[0,0] by total actual positives cm[0,0]+ False Negatives cm[0,1]
sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity : ', sensitivity )

# Calculate specificity, which is the ability to correctly classify true negatives
# Formula: True Negatives cm[1,1] by total actual negatives cm[1,0] + True Negatives cm[1,1]

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity : ', specificity)
# Out:
# Sensitivity :  0.9645892351274787
# Specificity :  0.951332560834299

# %%
# Binarize the true labels for ROC curve computation
ytest_lung_colon_image_set_df_bin = label_binarize(y_true, classes=list(range(5)))
# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
# Dictionaries for FPR, TPR and AUC of each class
for i in range(5):
    # Use y_pred_prob instead of y_pred to get probability scores
    fpr[i], tpr[i], _ = roc_curve(ytest_lung_colon_image_set_df_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Plot a new figure for ROC curves
matplib.figure(figsize=(8, 6))  # Create a new figure with a size of 8x6 inches.
for i in range(5):  # Loop through 5 classes (assumes you have multi-class data).
    matplib.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
    # Plot the ROC curve for each class using False Positive Rate (fpr) and True Positive Rate (tpr).
    # Add a label that includes the class index and its AUC (Area Under the Curve).

matplib.plot([0, 1], [0, 1], 'k--')
# Plot a diagonal reference line (y=x) in black dashed style ('k--').

# This represents the performance of a random classifier.

matplib.xlim([0.0, 1.0])  # Set the x-axis limits to range from 0 to 1.

matplib.ylim([0.0, 1.05])  # Set the y-axis limits to range from 0 to slightly above 1 for clarity.

matplib.xlabel('False Positive Rate')  # Label the x-axis as "False Positive Rate".
matplib.ylabel('True Positive Rate')  # Label the y-axis as "True Positive Rate".

matplib.title('Receiver Operating Characteristic (ROC) Curve - Test Set')
# Add a title to the plot describing it as an ROC curve for the test set.

matplib.legend(loc="lower right")
# Add a legend in the lower right corner to identify the curves for each class.

matplib.show()  # Display the finalized ROC curve plot.
